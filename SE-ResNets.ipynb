# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchsummary
import sklearn
from sklearn import metrics
from sklearn import naive_bayes

# %%
class BasicResidualSEBlock(nn.Module):

    expansion = 1

    def __init__(self, in_channels, out_channels, stride, r=16):
        super().__init__()

        self.residual = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, stride=stride, padding=1),
            nn.Dropout(),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),

            nn.Conv2d(out_channels, out_channels * self.expansion, 3, padding=1),
            nn.Dropout(),
            nn.BatchNorm2d(out_channels * self.expansion),
            nn.ReLU(inplace=True)
        )

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels * self.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels * self.expansion, 1, stride=stride),
                nn.BatchNorm2d(out_channels * self.expansion)
            )

        self.squeeze = nn.AdaptiveAvgPool2d(1)
        self.excitation = nn.Sequential(
            nn.Linear(out_channels * self.expansion, out_channels * self.expansion // r),
            nn.ReLU(inplace=True),
            nn.Linear(out_channels * self.expansion // r, out_channels * self.expansion),
            nn.Sigmoid()
        )

    def forward(self, x):
        shortcut = self.shortcut(x)
        residual = self.residual(x)

        squeeze = self.squeeze(residual)
        squeeze = squeeze.view(squeeze.size(0), -1)
        excitation = self.excitation(squeeze)
        excitation = excitation.view(residual.size(0), residual.size(1), 1, 1)

        x = residual * excitation.expand_as(residual) + shortcut

        return F.relu(x)

# %%
class SEResNet(nn.Module):

    def __init__(self, block, block_num, class_num=2):
        super().__init__()

        self.in_channels = 16

        self.pre = nn.Sequential(
            nn.Conv2d(1, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True)
        )

        self.stage1 = self._make_stage(block, block_num[0], 16, 1)
        self.stage2 = self._make_stage(block, block_num[1], 32, 2)
        self.stage3 = self._make_stage(block, block_num[2], 64, 2)
        self.stage4 = self._make_stage(block, block_num[3], 128, 2)

        self.linear = nn.Linear(self.in_channels, class_num)

    def forward(self, x):
        x = self.pre(x)

        x = self.stage1(x)
        x = self.stage2(x)
        x = self.stage3(x)
        x = self.stage4(x)

        x = F.adaptive_avg_pool2d(x, 1)
        x = x.view(x.size(0), -1)

        x = self.linear(x)

        return x


    def _make_stage(self, block, num, out_channels, stride):

        layers = []
        layers.append(block(self.in_channels, out_channels, stride))
        self.in_channels = out_channels * block.expansion

        while num - 1:
            layers.append(block(self.in_channels, out_channels, 1))
            num -= 1

        return nn.Sequential(*layers)

def seresnets():
    return SEResNet(BasicResidualSEBlock, [3, 4, 6, 3])

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
net = seresnets()
net.to(device)
torchsummary.summary(net, input_size=(1, 48, 48))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 48, 48]             160
#        BatchNorm2d-2           [-1, 16, 48, 48]              32
#               ReLU-3           [-1, 16, 48, 48]               0
#             Conv2d-4           [-1, 16, 48, 48]           2,320
#            Dropout-5           [-1, 16, 48, 48]               0
#        BatchNorm2d-6           [-1, 16, 48, 48]              32
#               ReLU-7           [-1, 16, 48, 48]               0
#             Conv2d-8           [-1, 16, 48, 48]           2,320
#            Dropout-9           [-1, 16, 48, 48]               0
#       BatchNorm2d-10           [-1, 16, 48, 48]              32
#              ReLU-11           [-1, 16, 48, 48]               0
# AdaptiveAvgPool2d-12             [-1, 16, 1, 1]               0
#            Linear-13                    [-1, 1]              17
#              ReLU-14                    [-1, 1]               0
#            Linear-15                   [-1, 16]              32
#           Sigmoid-16                   [-1, 16]               0
# BasicResidualSEBlock-17           [-1, 16, 48, 48]               0
#            Conv2d-18           [-1, 16, 48, 48]           2,320
#           Dropout-19           [-1, 16, 48, 48]               0
#       BatchNorm2d-20           [-1, 16, 48, 48]              32
#              ReLU-21           [-1, 16, 48, 48]               0
#            Conv2d-22           [-1, 16, 48, 48]           2,320
#           Dropout-23           [-1, 16, 48, 48]               0
#       BatchNorm2d-24           [-1, 16, 48, 48]              32
#              ReLU-25           [-1, 16, 48, 48]               0
# AdaptiveAvgPool2d-26             [-1, 16, 1, 1]               0
#            Linear-27                    [-1, 1]              17
#              ReLU-28                    [-1, 1]               0
#            Linear-29                   [-1, 16]              32
#           Sigmoid-30                   [-1, 16]               0
# BasicResidualSEBlock-31           [-1, 16, 48, 48]               0
#            Conv2d-32           [-1, 16, 48, 48]           2,320
#           Dropout-33           [-1, 16, 48, 48]               0
#       BatchNorm2d-34           [-1, 16, 48, 48]              32
#              ReLU-35           [-1, 16, 48, 48]               0
#            Conv2d-36           [-1, 16, 48, 48]           2,320
#           Dropout-37           [-1, 16, 48, 48]               0
#       BatchNorm2d-38           [-1, 16, 48, 48]              32
#              ReLU-39           [-1, 16, 48, 48]               0
# AdaptiveAvgPool2d-40             [-1, 16, 1, 1]               0
#            Linear-41                    [-1, 1]              17
#              ReLU-42                    [-1, 1]               0
#            Linear-43                   [-1, 16]              32
#           Sigmoid-44                   [-1, 16]               0
# BasicResidualSEBlock-45           [-1, 16, 48, 48]               0
#            Conv2d-46           [-1, 32, 24, 24]             544
#       BatchNorm2d-47           [-1, 32, 24, 24]              64
#            Conv2d-48           [-1, 32, 24, 24]           4,640
#           Dropout-49           [-1, 32, 24, 24]               0
#       BatchNorm2d-50           [-1, 32, 24, 24]              64
#              ReLU-51           [-1, 32, 24, 24]               0
#            Conv2d-52           [-1, 32, 24, 24]           9,248
#           Dropout-53           [-1, 32, 24, 24]               0
#       BatchNorm2d-54           [-1, 32, 24, 24]              64
#              ReLU-55           [-1, 32, 24, 24]               0
# AdaptiveAvgPool2d-56             [-1, 32, 1, 1]               0
#            Linear-57                    [-1, 2]              66
#              ReLU-58                    [-1, 2]               0
#            Linear-59                   [-1, 32]              96
#           Sigmoid-60                   [-1, 32]               0
# BasicResidualSEBlock-61           [-1, 32, 24, 24]               0
#            Conv2d-62           [-1, 32, 24, 24]           9,248
#           Dropout-63           [-1, 32, 24, 24]               0
#       BatchNorm2d-64           [-1, 32, 24, 24]              64
#              ReLU-65           [-1, 32, 24, 24]               0
#            Conv2d-66           [-1, 32, 24, 24]           9,248
#           Dropout-67           [-1, 32, 24, 24]               0
#       BatchNorm2d-68           [-1, 32, 24, 24]              64
#              ReLU-69           [-1, 32, 24, 24]               0
# AdaptiveAvgPool2d-70             [-1, 32, 1, 1]               0
#            Linear-71                    [-1, 2]              66
#              ReLU-72                    [-1, 2]               0
#            Linear-73                   [-1, 32]              96
#           Sigmoid-74                   [-1, 32]               0
# BasicResidualSEBlock-75           [-1, 32, 24, 24]               0
#            Conv2d-76           [-1, 32, 24, 24]           9,248
#           Dropout-77           [-1, 32, 24, 24]               0
#       BatchNorm2d-78           [-1, 32, 24, 24]              64
#              ReLU-79           [-1, 32, 24, 24]               0
#            Conv2d-80           [-1, 32, 24, 24]           9,248
#           Dropout-81           [-1, 32, 24, 24]               0
#       BatchNorm2d-82           [-1, 32, 24, 24]              64
#              ReLU-83           [-1, 32, 24, 24]               0
# AdaptiveAvgPool2d-84             [-1, 32, 1, 1]               0
#            Linear-85                    [-1, 2]              66
#              ReLU-86                    [-1, 2]               0
#            Linear-87                   [-1, 32]              96
#           Sigmoid-88                   [-1, 32]               0
# BasicResidualSEBlock-89           [-1, 32, 24, 24]               0
#            Conv2d-90           [-1, 32, 24, 24]           9,248
#           Dropout-91           [-1, 32, 24, 24]               0
#       BatchNorm2d-92           [-1, 32, 24, 24]              64
#              ReLU-93           [-1, 32, 24, 24]               0
#            Conv2d-94           [-1, 32, 24, 24]           9,248
#           Dropout-95           [-1, 32, 24, 24]               0
#       BatchNorm2d-96           [-1, 32, 24, 24]              64
#              ReLU-97           [-1, 32, 24, 24]               0
# AdaptiveAvgPool2d-98             [-1, 32, 1, 1]               0
#            Linear-99                    [-1, 2]              66
#             ReLU-100                    [-1, 2]               0
#           Linear-101                   [-1, 32]              96
#          Sigmoid-102                   [-1, 32]               0
# BasicResidualSEBlock-103           [-1, 32, 24, 24]               0
#           Conv2d-104           [-1, 64, 12, 12]           2,112
#      BatchNorm2d-105           [-1, 64, 12, 12]             128
#           Conv2d-106           [-1, 64, 12, 12]          18,496
#          Dropout-107           [-1, 64, 12, 12]               0
#      BatchNorm2d-108           [-1, 64, 12, 12]             128
#             ReLU-109           [-1, 64, 12, 12]               0
#           Conv2d-110           [-1, 64, 12, 12]          36,928
#          Dropout-111           [-1, 64, 12, 12]               0
#      BatchNorm2d-112           [-1, 64, 12, 12]             128
#             ReLU-113           [-1, 64, 12, 12]               0
# AdaptiveAvgPool2d-114             [-1, 64, 1, 1]               0
#           Linear-115                    [-1, 4]             260
#             ReLU-116                    [-1, 4]               0
#           Linear-117                   [-1, 64]             320
#          Sigmoid-118                   [-1, 64]               0
# BasicResidualSEBlock-119           [-1, 64, 12, 12]               0
#           Conv2d-120           [-1, 64, 12, 12]          36,928
#          Dropout-121           [-1, 64, 12, 12]               0
#      BatchNorm2d-122           [-1, 64, 12, 12]             128
#             ReLU-123           [-1, 64, 12, 12]               0
#           Conv2d-124           [-1, 64, 12, 12]          36,928
#          Dropout-125           [-1, 64, 12, 12]               0
#      BatchNorm2d-126           [-1, 64, 12, 12]             128
#             ReLU-127           [-1, 64, 12, 12]               0
# AdaptiveAvgPool2d-128             [-1, 64, 1, 1]               0
#           Linear-129                    [-1, 4]             260
#             ReLU-130                    [-1, 4]               0
#           Linear-131                   [-1, 64]             320
#          Sigmoid-132                   [-1, 64]               0
# BasicResidualSEBlock-133           [-1, 64, 12, 12]               0
#           Conv2d-134           [-1, 64, 12, 12]          36,928
#          Dropout-135           [-1, 64, 12, 12]               0
#      BatchNorm2d-136           [-1, 64, 12, 12]             128
#             ReLU-137           [-1, 64, 12, 12]               0
#           Conv2d-138           [-1, 64, 12, 12]          36,928
#          Dropout-139           [-1, 64, 12, 12]               0
#      BatchNorm2d-140           [-1, 64, 12, 12]             128
#             ReLU-141           [-1, 64, 12, 12]               0
# AdaptiveAvgPool2d-142             [-1, 64, 1, 1]               0
#           Linear-143                    [-1, 4]             260
#             ReLU-144                    [-1, 4]               0
#           Linear-145                   [-1, 64]             320
#          Sigmoid-146                   [-1, 64]               0
# BasicResidualSEBlock-147           [-1, 64, 12, 12]               0
#           Conv2d-148           [-1, 64, 12, 12]          36,928
#          Dropout-149           [-1, 64, 12, 12]               0
#      BatchNorm2d-150           [-1, 64, 12, 12]             128
#             ReLU-151           [-1, 64, 12, 12]               0
#           Conv2d-152           [-1, 64, 12, 12]          36,928
#          Dropout-153           [-1, 64, 12, 12]               0
#      BatchNorm2d-154           [-1, 64, 12, 12]             128
#             ReLU-155           [-1, 64, 12, 12]               0
# AdaptiveAvgPool2d-156             [-1, 64, 1, 1]               0
#           Linear-157                    [-1, 4]             260
#             ReLU-158                    [-1, 4]               0
#           Linear-159                   [-1, 64]             320
#          Sigmoid-160                   [-1, 64]               0
# BasicResidualSEBlock-161           [-1, 64, 12, 12]               0
#           Conv2d-162           [-1, 64, 12, 12]          36,928
#          Dropout-163           [-1, 64, 12, 12]               0
#      BatchNorm2d-164           [-1, 64, 12, 12]             128
#             ReLU-165           [-1, 64, 12, 12]               0
#           Conv2d-166           [-1, 64, 12, 12]          36,928
#          Dropout-167           [-1, 64, 12, 12]               0
#      BatchNorm2d-168           [-1, 64, 12, 12]             128
#             ReLU-169           [-1, 64, 12, 12]               0
# AdaptiveAvgPool2d-170             [-1, 64, 1, 1]               0
#           Linear-171                    [-1, 4]             260
#             ReLU-172                    [-1, 4]               0
#           Linear-173                   [-1, 64]             320
#          Sigmoid-174                   [-1, 64]               0
# BasicResidualSEBlock-175           [-1, 64, 12, 12]               0
#           Conv2d-176           [-1, 64, 12, 12]          36,928
#          Dropout-177           [-1, 64, 12, 12]               0
#      BatchNorm2d-178           [-1, 64, 12, 12]             128
#             ReLU-179           [-1, 64, 12, 12]               0
#           Conv2d-180           [-1, 64, 12, 12]          36,928
#          Dropout-181           [-1, 64, 12, 12]               0
#      BatchNorm2d-182           [-1, 64, 12, 12]             128
#             ReLU-183           [-1, 64, 12, 12]               0
# AdaptiveAvgPool2d-184             [-1, 64, 1, 1]               0
#           Linear-185                    [-1, 4]             260
#             ReLU-186                    [-1, 4]               0
#           Linear-187                   [-1, 64]             320
#          Sigmoid-188                   [-1, 64]               0
# BasicResidualSEBlock-189           [-1, 64, 12, 12]               0
#           Conv2d-190            [-1, 128, 6, 6]           8,320
#      BatchNorm2d-191            [-1, 128, 6, 6]             256
#           Conv2d-192            [-1, 128, 6, 6]          73,856
#          Dropout-193            [-1, 128, 6, 6]               0
#      BatchNorm2d-194            [-1, 128, 6, 6]             256
#             ReLU-195            [-1, 128, 6, 6]               0
#           Conv2d-196            [-1, 128, 6, 6]         147,584
#          Dropout-197            [-1, 128, 6, 6]               0
#      BatchNorm2d-198            [-1, 128, 6, 6]             256
#             ReLU-199            [-1, 128, 6, 6]               0
# AdaptiveAvgPool2d-200            [-1, 128, 1, 1]               0
#           Linear-201                    [-1, 8]           1,032
#             ReLU-202                    [-1, 8]               0
#           Linear-203                  [-1, 128]           1,152
#          Sigmoid-204                  [-1, 128]               0
# BasicResidualSEBlock-205            [-1, 128, 6, 6]               0
#           Conv2d-206            [-1, 128, 6, 6]         147,584
#          Dropout-207            [-1, 128, 6, 6]               0
#      BatchNorm2d-208            [-1, 128, 6, 6]             256
#             ReLU-209            [-1, 128, 6, 6]               0
#           Conv2d-210            [-1, 128, 6, 6]         147,584
#          Dropout-211            [-1, 128, 6, 6]               0
#      BatchNorm2d-212            [-1, 128, 6, 6]             256
#             ReLU-213            [-1, 128, 6, 6]               0
# AdaptiveAvgPool2d-214            [-1, 128, 1, 1]               0
#           Linear-215                    [-1, 8]           1,032
#             ReLU-216                    [-1, 8]               0
#           Linear-217                  [-1, 128]           1,152
#          Sigmoid-218                  [-1, 128]               0
# BasicResidualSEBlock-219            [-1, 128, 6, 6]               0
#           Conv2d-220            [-1, 128, 6, 6]         147,584
#          Dropout-221            [-1, 128, 6, 6]               0
#      BatchNorm2d-222            [-1, 128, 6, 6]             256
#             ReLU-223            [-1, 128, 6, 6]               0
#           Conv2d-224            [-1, 128, 6, 6]         147,584
#          Dropout-225            [-1, 128, 6, 6]               0
#      BatchNorm2d-226            [-1, 128, 6, 6]             256
#             ReLU-227            [-1, 128, 6, 6]               0
# AdaptiveAvgPool2d-228            [-1, 128, 1, 1]               0
#           Linear-229                    [-1, 8]           1,032
#             ReLU-230                    [-1, 8]               0
#           Linear-231                  [-1, 128]           1,152
#          Sigmoid-232                  [-1, 128]               0
# BasicResidualSEBlock-233            [-1, 128, 6, 6]               0
#           Linear-234                    [-1, 2]             258
# ================================================================
# Total params: 1,346,253
# Trainable params: 1,346,253
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 18.76
# Params size (MB): 5.14
# Estimated Total Size (MB): 23.91
# ----------------------------------------------------------------
